# %%
import napari_hydra_image_processor as nhip
import numpy as np
from skimage.io import imread

# %%
image = np.random.random((12,128,128))

# %%
blobs = imread("blobs.tif")

# %%
nhip.gaussian(blobs, sigma_x=5, sigma_y=1)
# Out:
# StackViewNDArray([[ 30,  30,  29, ..., 227, 227, 227],
#                   [ 33,  32,  32, ..., 232, 232, 232],
#                   [ 35,  34,  34, ..., 238, 238, 238],
#                   ...,
#                   [ 71,  70,  70, ...,  49,  48,  48],
#                   [ 74,  73,  72, ...,  50,  49,  49],
#                   [ 76,  75,  74, ...,  51,  50,  49]], dtype=uint8)

# %%
nhip.median_filter(blobs, radius_x=5, radius_y=1, radius_z=1)
# Out:
# StackViewNDArray([[ 24,  24,  32, ..., 240, 240, 232],
#                   [ 32,  32,  32, ..., 240, 240, 240],
#                   [ 40,  32,  32, ..., 248, 240, 240],
#                   ...,
#                   [ 72,  72,  72, ...,  48,  48,  48],
#                   [ 80,  80,  72, ...,  48,  48,  48],
#                   [ 80,  80,  80, ...,  48,  48,  48]], dtype=uint8)

# %%
nhip.opener(blobs, radius_x=10, radius_y=10)
# Out:
# StackViewNDArray([[ 16,  16,  16, ..., 200, 200, 200],
#                   [ 16,  16,  16, ..., 200, 200, 200],
#                   [ 16,  16,  16, ..., 200, 200, 200],
#                   ...,
#                   [ 40,  40,  40, ...,  40,  40,  40],
#                   [ 40,  40,  40, ...,  40,  40,  40],
#                   [ 40,  40,  40, ...,  40,  40,  40]], dtype=uint8)

# %%
nhip.closure(blobs, radius_x=5, radius_y=5)
# Out:
# StackViewNDArray([[ 64,  56,  56, ..., 248, 248, 248],
#                   [ 64,  56,  56, ..., 248, 248, 248],
#                   [ 64,  56,  56, ..., 248, 248, 248],
#                   ...,
#                   [ 80,  80,  80, ...,  48,  48,  48],
#                   [ 80,  80,  80, ...,  48,  48,  48],
#                   [ 96,  88,  80, ...,  48,  48,  48]], dtype=uint8)

# %%
nhip.laplacian_of_gaussian(blobs, sigma_x=5, sigma_y=1, sigma_z=1)
# Out:
# StackViewNDArray([[  7.2836256,  15.7498455,  22.71377  , ...,
#                    -34.808464 , -19.800602 ,  -2.0386992],
#                   [  2.461248 ,  11.469894 ,  19.03059  , ...,
#                    -40.14826  , -25.997108 ,  -9.198065 ],
#                   [ -1.3875694,   7.8431797,  15.714356 , ...,
#                    -43.080715 , -30.090166 , -14.61974  ],
#                   ...,
#                   [ -9.780464 , -10.91407  , -11.134679 , ...,
#                     27.984653 ,  21.257307 ,  12.093693 ],
#                   [-13.639395 , -14.69734  , -14.645679 , ...,
#                     35.355827 ,  27.316597 ,  16.24626  ],
#                   [-15.946659 , -16.393679 , -15.63809  , ...,
#                     39.61036  ,  30.901966 ,  18.778996 ]], dtype=float32)

# %%
nhip.high_pass_filter(blobs, sigma_x=5, sigma_y=5)
# Out:
# StackViewNDArray([[ 4,  0,  0, ...,  0,  0,  0],
#                   [19,  3,  0, ...,  0,  0,  0],
#                   [27, 11,  0, ...,  5,  0,  0],
#                   ...,
#                   [ 7, 15, 16, ...,  0,  0,  0],
#                   [14, 14, 15, ...,  0,  0,  0],
#                   [29, 21, 14, ...,  0,  0,  0]], dtype=uint8)

# %%
nhip.max_filter(blobs, radius_x=5, radius_y=5)
# Out:
# StackViewNDArray([[ 64,  64,  64, ..., 248, 248, 248],
#                   [ 64,  64,  64, ..., 248, 248, 248],
#                   [ 64,  64,  64, ..., 248, 248, 248],
#                   ...,
#                   [ 96,  96,  96, ...,  56,  56,  56],
#                   [ 96,  96,  96, ...,  56,  56,  56],
#                   [ 96,  96,  96, ...,  48,  48,  48]], dtype=uint8)

# %%
nhip.mean_filter(blobs, radius_x=5, radius_y=5)
# Out:
# StackViewNDArray([[ 35,  35,  35, ..., 237, 236, 235],
#                   [ 37,  36,  36, ..., 237, 236, 235],
#                   [ 38,  37,  36, ..., 236, 235, 234],
#                   ...,
#                   [ 69,  68,  67, ...,  47,  48,  48],
#                   [ 70,  69,  68, ...,  48,  48,  48],
#                   [ 72,  70,  69, ...,  47,  48,  48]], dtype=uint8)

# %%
nhip.min_filter(blobs, radius_x=5, radius_y=5)
# Out:
# StackViewNDArray([[ 16,  16,  16, ..., 200, 200, 200],
#                   [ 16,  16,  16, ..., 200, 200, 200],
#                   [ 16,  16,  16, ..., 200, 200, 200],
#                   ...,
#                   [ 56,  56,  56, ...,  40,  40,  40],
#                   [ 56,  56,  56, ...,  40,  48,  48],
#                   [ 56,  56,  56, ...,  40,  48,  48]], dtype=uint8)

# %%
nhip.var_filter(blobs, radius_x=5, radius_y=5)
# Out:
# StackViewNDArray([[129, 116, 103, ..., 132, 143, 150],
#                   [136, 122, 112, ..., 117, 125, 130],
#                   [137, 124, 117, ..., 105, 111, 115],
#                   ...,
#                   [ 80,  84,  85, ...,   8,   7,   9],
#                   [ 75,  81,  84, ...,   4,   2,   2],
#                   [ 69,  77,  82, ...,   2,   0,   0]], dtype=uint8)

# %%
nhip.std_filter(blobs, radius_x=5, radius_y=5)
# Out:
# StackViewNDArray([[11, 10, 10, ..., 11, 11, 12],
#                   [11, 11, 10, ..., 10, 11, 11],
#                   [11, 11, 10, ..., 10, 10, 10],
#                   ...,
#                   [ 8,  9,  9, ...,  2,  2,  3],
#                   [ 8,  9,  9, ...,  2,  1,  1],
#                   [ 8,  8,  9, ...,  1,  0,  0]], dtype=uint8)

# %%
nhip.non_local_means(blobs, 0.1, 15, 7)
# Out:
# StackViewNDArray([[ 40,  36,  31, ..., 227, 228, 232],
#                   [ 42,  36,  31, ..., 232, 232, 237],
#                   [ 42,  40,  36, ..., 232, 237, 237],
#                   ...,
#                   [ 58,  58,  59, ...,  47,  47,  48],
#                   [ 55,  57,  57, ...,  47,  47,  47],
#                   [ 50,  53,  55, ...,  47,  47,  47]], dtype=uint8)

# %%
nhip.wiener_filter(blobs, radius_x=7, radius_y=7, noise_variance=1000)
# Out:
# StackViewNDArray([[ 36,  35,  34, ..., 237, 237, 236],
#                   [ 37,  35,  34, ..., 236, 236, 235],
#                   [ 37,  36,  35, ..., 236, 235, 235],
#                   ...,
#                   [ 63,  63,  62, ...,  48,  48,  47],
#                   [ 65,  64,  64, ...,  48,  48,  48],
#                   [ 67,  66,  65, ...,  48,  48,  47]], dtype=uint8)
